# %%
import pandas as pd
import folium

# 데이터 로딩
data_path = '인구_천명당_도시공원조성면적_시도.xlsx'
data = pd.read_excel(data_path)
data.columns = ['Region', 'Parks_per_1000_people', 'Total_park_area', 'Urban_population']
data = data[['Region', 'Parks_per_1000_people']]
data = data.drop(index=0)  # 첫 번째 행 제거

# 지도 생성
map_korea = folium.Map(location=[36.5, 127.5], zoom_start=7)

# 지역별 중심 좌표
locations = {
    '전국': [36, 127.5], '서울특별시': [37.5665, 126.9780], '부산광역시': [35.1796, 129.0756],
    '대구광역시': [35.8722, 128.6025], '인천광역시': [37.4563, 126.7052], '광주광역시': [35.1595, 126.8526],
    '대전광역시': [36.3504, 127.3845], '울산광역시': [35.5384, 129.3114], '세종특별자치시': [36.4803, 127.2890],
    '경기도': [37.4138, 127.5183], '강원도': [37.8854, 127.7298], '충청북도': [36.6359, 127.4913],
    '충청남도': [36.6588, 126.6728], '전라북도': [35.7175, 127.1530], '전라남도': [34.8679, 126.9910],
    '경상북도': [36.4919, 128.8889], '경상남도': [35.4606, 128.2132], '제주특별자치도': [33.4996, 126.5312]
}

# 마커 크기
marker_radius = 20  # 마커의 반경

# 지도에 원 마커 추가, 마커 내 텍스트 위치 조정
for index, row in data.iterrows():
    loc = locations.get(row['Region'])
    if loc:
        folium.CircleMarker(
            location=loc,
            radius=marker_radius,
            color='blue',
            fill=True,
            fill_color='blue',
            fill_opacity=0.7
        ).add_to(map_korea)
        folium.map.Marker(
            loc,
            icon=folium.DivIcon(
                icon_size=(40, 40),  # 텍스트 박스 크기 조정
                icon_anchor=(20, 20),  # 마커 중앙에 위치하도록 앵커 조정
                html=f'<div style="font-size: 12pt; color : white; text-align:center;">{row["Parks_per_1000_people"]}</div>'
            )
        ).add_to(map_korea)

# 지도 출력
map_korea
# Out:
# C:\Users\ddaah\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
# ...

# %%
import pandas as pd
import folium
from folium.plugins import FloatImage

# 데이터 로딩
data_path = '인구_천명당_도시공원조성면적_시도.xlsx'
data = pd.read_excel(data_path)
data.columns = ['Region', 'Parks_per_1000_people', 'Total_park_area', 'Urban_population']
data = data[['Region', 'Parks_per_1000_people']]
data = data.drop(index=0)  # 첫 번째 행 제거

# 지도 생성
map_korea = folium.Map(location=[36.5, 127.5], zoom_start=7)

# 지역별 중심 좌표
locations = {
    '전국': [36, 127.5], '서울특별시': [37.5665, 126.9780], '부산광역시': [35.1796, 129.0756],
    '대구광역시': [35.8722, 128.6025], '인천광역시': [37.4563, 126.7052], '광주광역시': [35.1595, 126.8526],
    '대전광역시': [36.3504, 127.3845], '울산광역시': [35.5384, 129.3114], '세종특별자치시': [36.4803, 127.2890],
    '경기도': [37.4138, 127.5183], '강원도': [37.8854, 127.7298], '충청북도': [36.6359, 127.4913],
    '충청남도': [36.6588, 126.6728], '전라북도': [35.7175, 127.1530], '전라남도': [34.8679, 126.9910],
    '경상북도': [36.4919, 128.8889], '경상남도': [35.4606, 128.2132], '제주특별자치도': [33.4996, 126.5312]
}

# 마커 크기
marker_radius = 20  # 마커의 반경

# 지도에 원 마커 추가, 마커 내 텍스트 위치 조정
for index, row in data.iterrows():
    loc = locations.get(row['Region'])
    if loc:
        folium.CircleMarker(
            location=loc,
            radius=marker_radius,
            color='blue',
            fill=True,
            fill_color='blue',
            fill_opacity=0.7
        ).add_to(map_korea)
        folium.map.Marker(
            loc,
            icon=folium.DivIcon(
                icon_size=(40, 40),  # 텍스트 박스 크기 조정
                icon_anchor=(20, 20),  # 마커 중앙에 위치하도록 앵커 조정
                html=f'<div style="font-size: 12pt; color : white; text-align:center;">{row["Parks_per_1000_people"]}</div>'
            )
        ).add_to(map_korea)

# 지도에 제목 추가
title_html = '''
             <h3 align="center" style="font-size:20px"><b>인구 천명당 도시공원조성 면적</b></h3>
             '''
map_korea.get_root().html.add_child(folium.Element(title_html))

# 지도 출력
map_korea
# Out:
# C:\Users\ddaah\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
# ...

# %%
import pandas as pd
import folium

# 데이터 로딩
data_path = '인구_천명당_도시공원조성면적_시도.xlsx'
data = pd.read_excel(data_path)
data.columns = ['Region', 'Parks_per_1000_people', 'Total_park_area', 'Urban_population']
data = data[['Region', 'Parks_per_1000_people']]
data = data.drop(index=0)  # 첫 번째 행 제거

# 지도 생성
map_korea = folium.Map(location=[36.5, 127.5], zoom_start=7)

# 지역별 중심 좌표
locations = {
    '전국': [36, 127.5], '서울특별시': [37.5665, 126.9780], '부산광역시': [35.1796, 129.0756],
    '대구광역시': [35.8722, 128.6025], '인천광역시': [37.4563, 126.7052], '광주광역시': [35.1595, 126.8526],
    '대전광역시': [36.3504, 127.3845], '울산광역시': [35.5384, 129.3114], '세종특별자치시': [36.4803, 127.2890],
    '경기도': [37.4138, 127.5183], '강원도': [37.8854, 127.7298], '충청북도': [36.6359, 127.4913],
    '충청남도': [36.6588, 126.6728], '전라북도': [35.7175, 127.1530], '전라남도': [34.8679, 126.9910],
    '경상북도': [36.4919, 128.8889], '경상남도': [35.4606, 128.2132], '제주특별자치도': [33.4996, 126.5312]
}

# 마커 크기
marker_radius = 20  # 마커의 반경

# 지도에 원 마커 추가, 마커 내 텍스트 위치 조정
for index, row in data.iterrows():
    loc = locations.get(row['Region'])
    if loc:
        folium.CircleMarker(
            location=loc,
            radius=marker_radius,
            color='blue',
            fill=True,
            fill_color='blue',
            fill_opacity=0.7
        ).add_to(map_korea)
        folium.map.Marker(
            loc,
            icon=folium.DivIcon(
                icon_size=(40, 40),  # 텍스트 박스 크기 조정
                icon_anchor=(20, 20),  # 마커 중앙에 위치하도록 앵커 조정
                html=f'<div style="font-size: 12pt; color : white; text-align:center;">{row["Parks_per_1000_people"]}</div>'
            )
        ).add_to(map_korea)

# 지도에 제목 추가
title_html = '''
    <h3 align="center" style="font-size:20px"><b>인구 천명당 도시공원조성 면적</b></h3>
    '''
map_korea.get_root().html.add_child(folium.Element(title_html))

# 지도 출력
map_korea
# Out:
# C:\Users\ddaah\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
# ...
